# %%
# Remember to use a Pairplot for this for numerical data,offers nice overall views

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df_ratings = pd.read_csv('../../data/IMDb_ratings.csv')

# %%
df_ratings.shape
# Out:
# (85855, 49)

# %%
df_ratings.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# ...

# %%
non_dem_vote = pd.DataFrame(df_ratings, columns= ["weighted_average_vote", "total_votes", "mean_vote", "median_vote", "votes_10", "votes_9", "votes_8", "votes_7", "votes_6", "votes_5", "votes_4", "votes_3", "votes_2", "votes_1"])

# %%
non_dem_vote
# Out:
#        weighted_average_vote  total_votes  mean_vote  median_vote  votes_10  \
# 0                        5.9          154        5.9          6.0        12
# 1                        6.1          589        6.3          6.0        57
# 2                        5.8          188        6.0          6.0         6
# 3                        5.2          446        5.3          5.0        15
# 4                        7.0         2237        6.9          7.0       210
# ...                      ...          ...        ...          ...       ...
# 85850                    5.3          398        5.5          6.0        13
# 85851                    7.7          724        7.9          8.0        65
# 85852                    7.9          265        7.8          8.0        63
# 85853                    6.4          194        9.4         10.0       176
# 85854                    6.7          102        6.8          7.0         4
#
# ...

# %%
# Dataframe with non-demographic association with votes
non_dem_vote.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_89c77_row0_col0, #T_89c77_row1_col1, #T_89c77_row2_col2, #T_89c77_row3_col3, #T_89c77_row4_col4, #T_89c77_row5_col5, #T_89c77_row6_col6, #T_89c77_row7_col7, #T_89c77_row8_col8, #T_89c77_row9_col9, #T_89c77_row10_col10, #T_89c77_row11_col11, #T_89c77_row12_col12, #T_89c77_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_89c77_row0_col1, #T_89c77_row0_col6, #T_89c77_row0_col8 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_89c77_row0_col2, #T_89c77_row4_col5, #T_89c77_row5_col4 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_89c77_row0_col3 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_89c77_row0_col4, #T_89c77_row0_col11, #T_89c77_row0_col12, #T_89c77_row11_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_89c77_row0_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_89c77_row0_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# ...

# %%
non_dem_vote.to_csv("../../data/non_dem_rat_vote.csv")

# %%
df_ratings.dtypes
# Out:
# imdb_title_id                 object
# weighted_average_vote        float64
# total_votes                    int64
# mean_vote                    float64
# median_vote                  float64
# votes_10                       int64
# votes_9                        int64
# votes_8                        int64
# votes_7                        int64
# votes_6                        int64
# votes_5                        int64
# votes_4                        int64
# votes_3                        int64
# votes_2                        int64
# votes_1                        int64
# allgenders_0age_avg_vote     float64
# allgenders_0age_votes        float64
# allgenders_18age_avg_vote    float64
# allgenders_18age_votes       float64
# allgenders_30age_avg_vote    float64
# allgenders_30age_votes       float64
# allgenders_45age_avg_vote    float64
# allgenders_45age_votes       float64
# males_allages_avg_vote       float64
# males_allages_votes          float64
# ...

# %%
dem_rats = pd.DataFrame(df_ratings, columns= ["allgenders_0age_avg_vote", "allgenders_0age_votes", "allgenders_18age_avg_vote", "allgenders_18age_votes", "allgenders_30age_avg_vote", "allgenders_30age_votes", "allgenders_45age_avg_vote", "allgenders_45age_votes", "males_allages_avg_vote", "males_allages_votes", "males_0age_avg_vote", "males_0age_votes", "males_18age_avg_vote", "males_18age_votes", "males_30age_avg_vote", "males_30age_votes", "males_45age_avg_vote", "males_45age_votes", "females_allages_avg_vote", "females_allages_votes", "females_0age_avg_vote", "females_0age_votes", "females_18age_avg_vote", "females_18age_votes", "females_30age_avg_vote", "females_30age_votes", "females_45age_avg_vote", "females_45age_votes", "top1000_voters_rating", "top1000_voters_votes", "us_voters_rating", "us_voters_votes", "non_us_voters_rating", "non_us_voters_votes"])

# %%
dem_rats.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e3875_row0_col0, #T_e3875_row1_col1, #T_e3875_row2_col2, #T_e3875_row3_col3, #T_e3875_row4_col4, #T_e3875_row5_col5, #T_e3875_row5_col15, #T_e3875_row5_col33, #T_e3875_row6_col6, #T_e3875_row7_col7, #T_e3875_row7_col17, #T_e3875_row8_col8, #T_e3875_row9_col9, #T_e3875_row10_col10, #T_e3875_row11_col11, #T_e3875_row12_col12, #T_e3875_row13_col13, #T_e3875_row14_col14, #T_e3875_row15_col5, #T_e3875_row15_col15, #T_e3875_row16_col16, #T_e3875_row17_col7, #T_e3875_row17_col17, #T_e3875_row18_col18, #T_e3875_row19_col19, #T_e3875_row20_col20, #T_e3875_row21_col21, #T_e3875_row22_col22, #T_e3875_row23_col23, #T_e3875_row24_col24, #T_e3875_row25_col25, #T_e3875_row26_col26, #T_e3875_row27_col27, #T_e3875_row28_col28, #T_e3875_row29_col29, #T_e3875_row30_col30, #T_e3875_row31_col31, #T_e3875_row32_col32, #T_e3875_row33_col5, #T_e3875_row33_col33 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...

# %%
gender_votes = pd.DataFrame(df_ratings, columns= ["total_votes", "males_allages_votes", "females_allages_votes"])
