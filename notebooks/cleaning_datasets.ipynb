# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df_mov_nam = pd.read_csv('../data/imdb_names.csv')
# Data has been scraped from the publicly available website https://www.imdb.com.
# All the movies with more than 100 votes have been scraped as of 01/01/2020.
# Out:
# /home/guillermo/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_mov_nam
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ...  \
# 0                          Alexander Black  ...
# 1                             Charles Tait  ...
# 2                                Urban Gad  ...
# 3                       Charles L. Gaskill  ...
# 4      Francesco Bertolini, Adolfo Padovan  ...
# ...                                    ...  ...
# 85850               Ludovic Colbeau-Justin  ...
# 85851                      Johan Nijenhuis  ...
# 85852                      Vineesh Aaradya  ...
# 85853                    Ahmet Faik Akinci  ...
# 85854                            Laura Jou  ...
#
#                                                   actors  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                  ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                              description avg_vote votes  \
# 0      The adventures of a female reporter in the 1890s.      5.9   154
# 1      True story of notorious Australian outlaw Ned ...      6.1   589
# 2      Two men of high rank are both wooing the beaut...      5.8   188
# 3      The fabled queen of Egypt's affair with Roman ...      5.2   446
# 4      Loosely adapted from Dante's Divine Comedy and...      7.0  2237
# ...                                                  ...      ...   ...
# 85850  A psychiatric hospital patient pretends to be ...      5.3   398
# 85851  A middle-aged veterinary surgeon believes his ...      7.7   724
# 85852                                                NaN      7.9   265
# 85853                                                NaN      6.4   194
# 85854  Pep, a 13-year-old boy, is in love with a girl...      6.7   102
#
#         budget  usa_gross_income worlwide_gross_income metascore  \
# 0          NaN               NaN                   NaN       NaN
# 1       $ 2250               NaN                   NaN       NaN
# 2          NaN               NaN                   NaN       NaN
# 3      $ 45000               NaN                   NaN       NaN
# 4          NaN               NaN                   NaN       NaN
# ...        ...               ...                   ...       ...
# 85850      NaN               NaN             $ 3507171       NaN
# 85851      NaN               NaN             $ 7299062       NaN
# 85852      NaN               NaN                   NaN       NaN
# 85853      NaN               NaN                $ 2833       NaN
# 85854      NaN               NaN               $ 59794       NaN
#
#       reviews_from_users  reviews_from_critics
# 0                    1.0                   2.0
# 1                    7.0                   7.0
# 2                    5.0                   2.0
# 3                   25.0                   3.0
# 4                   31.0                  14.0
# ...                  ...                   ...
# 85850                NaN                   4.0
# 85851                6.0                   4.0
# 85852                NaN                   NaN
# 85853                NaN                   NaN
# 85854                NaN                   2.0
#
# [85855 rows x 22 columns]

# %%
list(df_mov_nam['country'].unique())
# Movies can have more than one country of origin
# Out:
# ['USA',
#  'Australia',
#  'Germany, Denmark',
#  'Italy',
#  'Germany',
#  'Romania',
#  'France, USA',
#  'Denmark',
#  'France',
#  'Sweden',
#  'Belgium',
#  'USA, Canada',
#  'Hungary',
#  'Russia',
#  'Mexico',
#  'Canada',
#  'France, Belgium',
#  'Norway',
#  'Japan',
#  'Germany, Austria',
#  'UK',
#  'Soviet Union',
#  'Austria, Germany',
#  'Norway, Sweden',
#  'Chile',
#  'UK, Germany',
#  'India, Germany',
#  'Austria',
#  'Switzerland, France',
#  'France, Germany',
#  'China, Hong Kong',
#  'India, UK, Germany',
#  'Germany, Soviet Union',
#  'Spain',
#  'Czechoslovakia',
#  'UK, Isle Of Man',
#  'UK, India, Germany',
#  'UK, Sweden',
#  'UK, USA',
#  'Germany, UK',
#  'Czechoslovakia, Germany',
#  'India',
#  'Germany, France',
#  'Brazil',
#  'Germany, USA',
#  'Canada, USA',
#  'Czechoslovakia, Austria',
#  'France, Hungary',
#  'Portugal',
#  'UK, France',
#  'UK, France, Germany',
#  'USA, Mexico',
#  'Turkey',
#  'USA, Argentina',
#  'Poland, USA',
#  'Czechoslovakia, France',
#  'Netherlands',
#  'Finland',
#  'Canada, UK',
#  'Poland',
#  'Switzerland',
#  'Italy, Spain',
#  'France, Italy',
#  'Argentina',
#  'USA, UK',
#  'Spain, France',
#  'Mexico, USA',
#  'UK, Australia',
#  'Italy, France, Germany',
#  'Spain, West Germany',
#  'UK, Italy',
#  'Spain, Italy',
#  'China',
#  'Italy, France',
#  'Norway, France',
#  'Italy, UK',
#  'Yugoslavia',
#  'Switzerland, USA',
#  'France, Netherlands',
#  'Italy, USA',
#  'Greece',
#  'East Germany',
#  'USA, France, UK',
#  'Egypt',
#  'France, Spain, USA',
#  'West Germany',
#  'USA, West Germany',
#  'France, Italy, UK',
#  'France, UK, India, USA',
#  'India, USA',
#  'Spain, Argentina',
#  'UK, Spain',
#  'UK, Italy, USA',
#  'West Germany, Switzerland',
#  'West Germany, USA',
#  'France, Mexico',
#  'West Germany, Austria',
#  'Austria, USA',
#  'Austria, West Germany',
#  'Canada, France',
#  'Albania, Soviet Union',
#  'Soviet Union, Bulgaria',
#  'Austria, Yugoslavia',
#  'Australia, USA',
#  'France, West Germany',
#  'France, UK',
#  'Italy, West Germany, Monaco',
#  'UK, New Zealand',
#  'Italy, France, USA',
#  'Italy, France, Spain',
#  'West Germany, Netherlands',
#  'Israel',
#  'France, Sweden',
#  'UK, Spain, USA',
#  'Japan, Hong Kong',
#  'Spain, USA',
#  'France, East Germany',
#  'USA, Japan',
#  'USA, Portugal',
#  'France, West Germany, Italy, Yugoslavia',
#  'UK, Japan',
#  'West Germany, Spain',
#  'UK, Norway',
#  'USA, Italy',
#  'Mexico, Cuba',
#  'Cuba, USA',
#  'France, Italy, Yugoslavia',
#  'Italy, France, West Germany, Yugoslavia',
#  'USA, Denmark',
#  'France, Italy, East Germany',
#  'France, Italy, West Germany',
#  'Ireland',
#  'Switzerland, West Germany, Spain',
#  'West Germany, France',
#  'Poland, West Germany',
#  'Italy, Yugoslavia',
#  'Czechoslovakia, Hungary',
#  'Italy, France, Yugoslavia',
#  'West Germany, France, Italy',
#  'Sweden, USA',
#  'Italy, West Germany, USA',
#  'Denmark, West Germany',
#  'France, Japan',
#  'Italy, Spain, France',
#  'France, Brazil, Italy',
#  'USA, Sweden',
#  'Finland, Soviet Union',
#  'Italy, France, UK',
#  'East Germany, Poland',
#  'Ireland, USA',
#  'East Germany, Bulgaria',
#  'UK, Australia, USA',
#  'Philippines',
#  'West Germany, Mexico',
#  'South Korea',
#  'Italy, France, West Germany',
#  'France, Italy, Yugoslavia, Liechtenstein',
#  'Italy, USA, Austria',
#  'France, Spain, Italy',
#  'France, Portugal',
#  'Yugoslavia, Croatia',
#  'Italy, West Germany',
#  'Italy, Japan',
#  'UK, Israel',
#  'Italy, Spain, West Germany, Monaco',
#  'France, Spain, West Germany',
#  'Spain, Italy, USA',
#  'UK, West Germany',
#  'Spain, Mexico',
#  'UK, South Africa',
#  'Italy, Austria',
#  'Japan, USA',
#  'France, Italy, USA',
#  'Italy, Spain, West Germany',
#  'Switzerland, West Germany, USA',
#  'West Germany, Italy, France',
#  'France, Austria',
#  'Cuba',
#  'Denmark, USA',
#  'Austria, France',
#  'Greece, France, USA',
#  'West Germany, France, Yugoslavia',
#  'France, Italy, Spain',
#  'Yugoslavia, USA',
#  'Switzerland, UK, USA',
#  'West Germany, Spain, Italy',
#  'France, Monaco',
#  'USA, Egypt',
#  'Philippines, USA',
#  'USA, Ireland',
#  'France, Italy, Hungary',
#  'USA, Spain',
#  'France, Italy, Turkey',
#  'Hong Kong',
#  'UK, Yugoslavia',
#  'France, West Germany, Italy',
#  'West Germany, France, Italy, Yugoslavia',
#  'Yugoslavia, UK',
#  'Puerto Rico, USA',
#  'West Germany, Italy, Yugoslavia',
#  'France, Canada',
#  'Greece, USA',
#  'West Germany, Italy, Liechtenstein',
#  'West Germany, Yugoslavia',
#  'Brazil, Argentina',
#  'Bulgaria',
#  'Spain, France, Italy',
#  'Mexico, Spain',
#  'Italy, Spain, West Germany, France',
#  'France, Italy, Japan, Netherlands',
#  'Spain, Austria, France',
#  'Cuba, Soviet Union',
#  'France, Spain',
#  'West Germany, France, Italy, Malta',
#  'Italy, France, West Germany, USA',
#  'West Germany, Denmark, France',
#  'France, Italy, Spain, West Germany',
#  'Italy, Egypt',
#  'Algeria, Italy',
#  'Lebanon',
#  'Switzerland, Spain',
#  'USA, France',
#  'France, Italy, West Germany, USA',
#  'Italy, Spain, Yugoslavia',
#  'France, Romania',
#  'Sri Lanka',
#  'West Germany, Spain, USA',
#  'UK, West Germany, Yugoslavia, USA',
#  'Italy, Soviet Union',
#  'Denmark, Sweden',
#  'UK, France, Italy',
#  'Austria, West Germany, Italy',
#  'Italy, France, Afghanistan, Egypt, Yugoslavia',
#  'France, Italy, Spain, Morocco',
#  'Czechoslovakia, UK',
#  'USA, Philippines',
#  'Soviet Union, Kyrgyzstan',
#  'South Africa',
#  'USA, India',
#  'Italy, Spain, USA',
#  'Soviet Union, USA',
#  'West Germany, Italy, Yugoslavia, France',
#  'Austria, Italy, Yugoslavia, Singapore',
#  'Italy, France, Austria',
#  'Spain, Italy, Austria, Liechtenstein',
#  'Italy, Austria, West Germany',
#  'Romania, France',
#  'UK, Israel, USA',
#  'Japan, Italy, USA',
#  'Austria, France, Italy',
#  'Taiwan, Hong Kong',
#  'Austria, Italy, France, West Germany',
#  'South Africa, USA',
#  'Senegal, France',
#  'France, Austria, USA',
#  'Spain, Argentina, USA',
#  'Denmark, Norway, Sweden',
#  'East Germany, Yugoslavia',
#  'Greece, France',
#  'Australia, UK',
#  'Spain, Italy, France',
#  'UK, Canada',
#  'Israel, West Germany',
#  'Bolivia',
#  'West Germany, Italy, Spain, Bulgaria',
#  'Spain, Italy, West Germany',
#  'Italy, West Germany, Yugoslavia',
#  'West Germany, Yugoslavia, USA',
#  'France, Bermuda, USA',
#  'Hungary, Soviet Union',
#  'South Korea, Japan',
#  'Greece, UK, USA',
#  'Italy, Morocco',
#  'UK, France, West Germany',
#  'UK, West Germany, Liechtenstein, Hong Kong',
#  'East Germany, West Germany',
#  'Czechoslovakia, Italy',
#  'West Germany, Italy, France, Lebanon, Hungary',
#  'Chile, Argentina',
#  'Italy, France, Yugoslavia, Spain',
#  'Denmark, Greece',
#  'West Germany, Austria, Italy, Spain',
#  'Soviet Union, Ukraine',
#  'West Germany, Spain, Portugal',
#  'Argentina, Spain',
#  'Hungary, USA',
#  'France, Mauritania',
#  'Italy, France, Algeria',
#  'Italy, Czechoslovakia',
#  'UK, Canada, USA',
#  'Sweden, West Germany',
#  'France, Italy, Mexico, USA',
#  'Italy, Israel',
#  'UK, West Germany, Spain',
#  'West Germany, Italy',
#  'Romania, West Germany',
#  'UK, France, Spain, USA',
#  'Liechtenstein, West Germany, Italy, USA',
#  'Hong Kong, USA',
#  'UK, Spain, Liechtenstein, USA',
#  'Italy, Bulgaria',
#  'France, Italy, Czechoslovakia',
#  'Iran, USA',
#  'Italy, West Germany, Romania',
#  'Italy, West Germany, Thailand, USA',
#  'France, Senegal',
#  'France, Italy, Mexico',
#  'France, Italy, Greece',
#  'Denmark, Iceland, Sweden',
#  'UK, West Germany, USA',
#  'East Germany, Soviet Union',
#  'Netherlands, France, West Germany, USA',
#  'Spain, Italy, France, West Germany, USA',
#  'West Germany, Italy, USA',
#  'Ireland, UK, West Germany, Hong Kong, Singapore',
#  'Italy, West Germany, Spain, Monaco',
#  'Liechtenstein, Spain, Italy, West Germany, UK',
#  'Romania, Italy',
#  'Yugoslavia, Italy, West Germany, USA',
#  'Italy, Monaco',
#  'Switzerland, France, Italy',
#  'France, Brazil, West Germany, USA',
#  'UK, West Germany, Italy, Spain, Liechtenstein, Turkey',
#  'Yugoslavia, Italy',
#  'France, Spain, West Germany, Italy',
#  'Iran',
#  'Italy, Japan, USA',
#  'West Germany, Spain, Liechtenstein',
#  'Finland, Sweden',
#  'Brazil, Italy, France',
#  'West Germany, Switzerland, Italy',
#  'Netherlands, Belgium',
#  'Spain, West Germany, Italy',
#  'West Germany, France, Luxembourg',
#  'Italy, West Germany, Spain, Liechtenstein',
#  'Netherlands, West Germany',
#  'Czechoslovakia, Belgium',
#  'Poland, Soviet Union',
#  'UK, Italy, West Germany',
#  'Soviet Union, Georgia',
#  'UK, France, USA',
#  'Israel, USA, West Germany',
#  'France, Belgium, Switzerland',
#  'Denmark, UK',
#  'France, Algeria',
#  'UK, Switzerland',
#  'Italy, Algeria',
#  'France, Italy, Venezuela',
#  'Spain, Brazil',
#  'Spain, West Germany, Italy, Liechtenstein, UK',
#  'Italy, Venezuela',
#  'Spain, France, Liechtenstein, Portugal',
#  'Croatia',
#  'West Germany, Switzerland, Hungary',
#  'West Germany, UK',
#  'Italy, France, Soviet Union, USA',
#  'Peru',
#  'Switzerland, West Germany',
#  'Italy, USA, West Germany',
#  'Taiwan',
#  'Italy, Spain, Morocco',
#  'Ireland, UK',
#  'Romania, France, Italy',
#  'USA, Denmark, Panama, UK',
#  'France, Italy, Belgium',
#  'Italy, Spain, Austria',
#  'Czechoslovakia, West Germany',
#  'France, Tunisia',
#  'West Germany, France, Italy, Czechoslovakia',
#  'Sweden, Yugoslavia',
#  'Spain, Greece, Italy',
#  'Italy, Australia',
#  'UK, Spain, West Germany',
#  'Belgium, France, Italy, Liechtenstein',
#  'Italy, Spain, Sweden',
#  'Italy, Spain, UK',
#  'Italy, Bolivia',
#  'Italy, Yugoslavia, USA',
#  'Sweden, UK, Spain',
#  'France, Czechoslovakia, Tunisia',
#  'Greece, UK',
#  'France, Spain, Italy, West Germany',
#  'East Germany, Soviet Union, Bulgaria, Yugoslavia',
#  'Italy, France, West Germany, Switzerland, Ireland',
#  'France, Italy, Canada',
#  'France, UK, USA',
#  'Italy, West Germany, Spain',
#  'UK, Denmark',
#  'USA, Spain, Liechtenstein',
#  'Italy, West Germany, Yugoslavia, Czechoslovakia',
#  'Belgium, France, West Germany',
#  'France, Italy, Romania',
#  'Belgium, Netherlands',
#  'Italy, Spain, UK, France',
#  'West Germany, Spain, UK',
#  'UK, Italy, West Germany, Spain',
#  'Spain, Portugal',
#  'UK, Norway, USA',
#  'UK, France, Italy, Spain',
#  'France, Belgium, West Germany',
#  'West Germany, France, Israel',
#  'Yugoslavia, Italy, France, USA',
#  'Yugoslavia, West Germany',
#  'USA, East Germany, West Germany, Belgium, UK',
#  'Hong Kong, Taiwan',
#  'Italy, Haiti',
#  'Egypt, Algeria',
#  'Italy, Belgium',
#  'Italy, Netherlands',
#  'France, USA, Italy, West Germany',
#  'Italy, Monaco, France',
#  'Italy, West Germany, UK',
#  'Denmark, Sweden, USA',
#  'Canada, UK, USA',
#  'East Germany, Soviet Union, Bulgaria',
#  'France, USA, West Germany',
#  'Italy, West Germany, France, Monaco',
#  'Hong Kong, South Korea',
#  'Brazil, Italy',
#  'UK, Spain, Turkey',
#  'Spain, France, Italy, Cameroon',
#  'France, Italy, West Germany, Spain',
#  'UK, Italy, Spain',
#  'Italy, France, West Germany, Monaco',
#  'Syria',
#  'UK, Spain, Switzerland',
#  'Italy, France, Denmark',
#  'France, Iran, USA',
#  'Italy, France, West Germany, Spain',
#  'UK, France, West Germany, Italy, Spain',
#  'Angola, France',
#  'UK, France, Italy, West Germany, Spain',
#  'Italy, Denmark',
#  'Belgium, France',
#  'Sweden, Norway',
#  'Spain, France, Italy, Portugal, USA',
#  'Sweden, France',
#  'East Germany, Romania, Soviet Union',
#  'USA, UK, Israel',
#  'Italy, Spain, France, USA',
#  'Italy, West Germany, France',
#  'Sweden, Switzerland, West Germany',
#  'Switzerland, West Germany, Israel',
#  'Jamaica',
#  'Spain, Switzerland',
#  'UK, Hong Kong',
#  'Italy, Turkey',
#  'UK, Greece',
#  'Spain, France, Portugal',
#  'Spain, Italy, UK',
#  'Soviet Union, Italy',
#  'Spain, Venezuela',
#  'East Germany, Bulgaria, Cuba',
#  'Spain, Ecuador',
#  'Spain, France, Andorra',
#  'France, Czechoslovakia',
#  'USA, Colombia, Philippines, Spain',
#  'France, Italy, Tunisia',
#  'India, Bangladesh',
#  'Senegal',
#  'Czechoslovakia, East Germany',
#  'UK, USA, Ireland',
#  'Switzerland, West Germany, Austria',
#  'Spain, Switzerland, USA, UK',
#  'Soviet Union, Japan',
#  'Chile, France',
#  'Mexico, Italy, Spain',
#  'Canada, Denmark',
#  'USA, Italy, France',
#  'East Germany, Czechoslovakia',
#  'Hong Kong, West Germany',
#  'Netherlands, UK, Belgium, USA',
#  'USA, France, Italy',
#  'Italy, Spain, Hong Kong, USA',
#  'West Germany, Austria, France, Italy',
#  'Yugoslavia, USA, Liechtenstein',
#  'France, Switzerland',
#  'USA, Canada, Argentina',
#  'Switzerland, UK, France, Italy, USA',
#  'France, West Germany, Canada',
#  'UK, Belgium, Spain',
#  'Italy, West Germany, France, Spain, UK, Iran',
#  'USA, Spain, Panama, UK',
#  'East Germany, Soviet Union, Romania',
#  'USA, Israel',
#  'France, Hong Kong, UK',
#  'Algeria',
#  'Belgium, Spain, France',
#  'West Germany, Iran',
#  'Switzerland, Israel, USA',
#  'Greece, West Germany',
#  'Israel, USA',
#  'Spain, Panama, UK, USA',
#  'Mexico, UK',
#  'Sweden, Denmark',
#  'France, Bulgaria',
#  'Ireland, Switzerland, USA',
#  'Australia, Hong Kong',
#  'Ethiopia',
#  'UK, Spain, Canada',
#  'UK, Austria, USA',
#  'Italy, Hong Kong',
#  'Soviet Union, Russia',
#  'Soviet Union, India',
#  'UK, USA, Canada',
#  'Yugoslavia, Czechoslovakia, Hungary, West Germany',
#  'France, West Germany, Spain',
#  'Italy, Canada',
#  'Italy, Hong Kong, Mexico',
#  'Italy, West Germany, Austria',
#  'Bulgaria, Hungary',
#  'Japan, France',
#  'West Germany, South Africa',
#  'Italy, Switzerland',
#  'South Korea, USA',
#  'Hong Kong, Singapore',
#  'UK, Italy, West Germany, USA',
#  'Argentina, USA',
#  'USA, Canada, France',
#  'Indonesia, Netherlands',
#  'Lebanon, Libya, Kuwait, Morocco, UK, Saudi Arabia, Egypt',
#  "Côte d'Ivoire, France, West Germany, Switzerland",
#  'Hong Kong, Malaysia',
#  'Czechoslovakia, Yugoslavia, USA',
#  'UK, Italy, Israel',
#  'Taiwan, Hong Kong, Japan',
#  'USA, Greece',
#  'Poland, UK',
#  'Suriname, Netherlands',
#  'Poland, Czechoslovakia',
#  'Sweden, Australia',
#  'Canada, USA, Italy',
#  'Sweden, Iceland',
#  'Italy, Spain, Australia',
#  'Hong Kong, Philippines',
#  'UK, West Germany, Italy',
#  'Switzerland, France, West Germany',
#  'Spain, Liechtenstein',
#  'UK, Belgium',
#  'West Germany, France, UK',
#  'Greece, France, West Germany',
#  'West Germany, Austria, USA',
#  'Romania, France, Soviet Union',
#  'West Germany, Italy, Iran, Spain, USA',
#  'USA, Netherlands',
#  'Italy, Greece',
#  'Venezuela',
#  'New Zealand',
#  'France, Ireland, Italy',
#  'France, Soviet Union',
#  'Sweden, Ireland',
#  'Mali',
#  'Spain, Mexico, Italy',
#  'USA, West Germany, Switzerland',
#  'Canada, France, Israel',
#  'Greece, Switzerland, USA',
#  'West Germany, Portugal',
#  'Italy, USA, Hong Kong',
#  'Sweden, France, West Germany, UK, Norway',
#  'USA, UK, Spain',
#  'Spain, Italy, Mexico',
#  'Indonesia',
#  'Romania, Czechoslovakia',
#  'France, UK, Japan',
#  'Netherlands, Australia, USA',
#  'USA, UK, Canada, Switzerland',
#  'West Germany, Israel, Italy',
#  'Sweden, Greece',
#  'West Germany, USA, Italy, France',
#  'Switzerland, UK',
#  'Vietnam',
#  'Poland, France',
#  'Indonesia, Japan, Philippines',
#  'West Germany, France, Poland, Yugoslavia',
#  'UK, Mexico',
#  'Mexico, Spain, Italy',
#  'South Korea, Thailand, Italy',
#  'Italy, West Germany, UK, France',
#  'Mexico, Spain, USA',
#  'Greece, Cyprus',
#  'France, West Germany, USA',
#  'Austria, Switzerland, West Germany',
#  'Italy, South Africa',
#  'USA, Hong Kong',
#  'France, Switzerland, West Germany, Austria',
#  'Taiwan, Hong Kong, South Korea',
#  'Netherlands, USA',
#  'France, Brazil, Argentina',
#  'Spain, France, West Germany',
#  'Romania, East Germany',
#  'Spain, Japan',
#  'Italy, Spain, Mexico',
#  'Cuba, Spain',
#  'Netherlands, West Germany, UK, Italy',
#  'UK, Italy, Netherlands, USA',
#  'Japan, Canada',
#  'South Africa, Botswana',
#  'Portugal, Brazil',
#  'Libya, USA',
#  'France, Italy, Germany',
#  'Greece, Italy, West Germany',
#  'Spain, Austria',
#  'UK, Nigeria, Kenya',
#  'Hong Kong, USA, Taiwan',
#  'USA, UK, Canada',
#  'Soviet Union, France, Switzerland',
#  'Finland, West Germany',
#  'Italy, Dominican Republic',
#  'Soviet Union, Finland',
#  'New Zealand, UK',
#  'Hong Kong, France, Greece',
#  'France, Mexico, Malta',
#  'USA, Spain, Mexico',
#  'Australia, New Zealand',
#  'West Germany, France, Austria',
#  'Yugoslavia, Czechoslovakia',
#  'Hong Kong, Thailand',
#  'USA, Mexico, UK',
#  'West Germany, Hungary, Austria',
#  'Sweden, UK',
#  'UK, USA, West Germany',
#  'Italy, USA, Japan',
#  'UK, Mexico, Italy',
#  'Australia, New Zealand, USA',
#  'UK, Egypt, Hungary',
#  'Belgium, France, Spain',
#  'Iceland',
#  'UK, USA, Italy',
#  'Italy, UK, Poland',
#  'Hungary, Italy',
#  'Poland, UK, Belgium, USA',
#  'Nicaragua, Cuba, Mexico, Costa Rica',
#  'France, Mexico, Spain',
#  'France, UK, West Germany, Switzerland',
#  'France, Hungary, West Germany',
#  'Australia, Taiwan',
#  'France, Poland',
#  'Hungary, West Germany, USA',
#  'Sweden, France, West Germany',
#  'West Germany, Peru',
#  'UK, India',
#  'Italy, Panama',
#  'Zambia, Sweden',
#  'Turkey, West Germany',
#  'Japan, Australia',
#  'Sweden, West Germany, Norway',
#  'West Germany, Philippines',
#  'West Germany, Canada',
#  'Mexico, Soviet Union',
#  'Soviet Union, Mexico, Italy',
#  'UK, France, West Germany, Japan, USA',
#  'Hong Kong, Japan',
#  'France, Switzerland, West Germany, UK, Hungary',
#  'France, Yugoslavia',
#  'USA, South Africa',
#  'Netherlands, UK, West Germany, France, Spain, Portugal, USA',
#  'Spain, USA, Italy',
#  'Belgium, France, Netherlands, Canada',
#  'Netherlands, Italy',
#  'Spain, Mexico, USA, Canada',
#  'Burkina Faso',
#  'Turkey, Switzerland, France',
#  'Austria, West Germany, France, Italy',
#  'France, Canada, Hungary',
#  'France, Italy, Algeria',
#  'Belgium, France, Italy',
#  'Bahamas, France, USA, Spain',
#  'Colombia',
#  'South Korea, Hong Kong',
#  'Switzerland, Portugal, UK',
#  'Mexico, France, West Germany',
#  'Israel, France',
#  'USA, Yugoslavia, Hong Kong',
#  'USA, Hungary',
#  'Iraq, UK',
#  'UK, New Zealand, Japan',
#  'New Zealand, USA',
#  'Norway, Denmark',
#  'Italy, Philippines',
#  'USA, Australia',
#  'France, Saudi Arabia, Aruba',
#  'France, Martinique',
#  'East Germany, Mongolia',
#  'Czechoslovakia, West Germany, Austria',
#  'France, West Germany, Portugal',
#  'France, Gabon',
#  'USA, France, Czechoslovakia, Italy',
#  'Tunisia, France',
#  'UK, USA, New Zealand',
#  'France, Liechtenstein, Switzerland',
#  'Mexico, USA, UK',
#  'UK, USA, Mexico',
#  'France, Italy, Soviet Union',
#  'USA, Italy, Malta',
#  'France, USA, Canada',
#  'UK, Mexico, USA',
#  'France, Spain, Panama',
#  'Iceland, Sweden',
#  'Italy, Brazil',
#  'Mexico, West Germany',
#  'Spain, USA, Puerto Rico',
#  'Italy, USA, Tunisia',
#  'Australia, Canada',
#  'Poland, Italy, West Germany',
#  'USA, Spain, Australia',
#  'New Zealand, Australia',
#  'Hong Kong, China',
#  'Greece, West Germany, Italy, UK',
#  'Turkey, France, UK',
#  'Egypt, France',
#  'Turkey, Sweden',
#  'Italy, France, West Germany, Spain, UK',
#  'USA, West Germany, UK',
#  'Netherlands, Spain',
#  'Italy, USA, Netherlands',
#  'USA, France, Japan',
#  'Czechoslovakia, UK, USA',
#  'Soviet Union, Norway',
#  'Belgium, Luxembourg, West Germany',
#  'France, Switzerland, UK',
#  'Brazil, USA',
#  'Switzerland, Italy, West Germany',
#  'Sweden, Canada',
#  'Japan, China',
#  'Yugoslavia, Hungary, Austria, West Germany',
#  'Venezuela, France',
#  'Czechoslovakia, West Germany, Italy, Austria',
#  'Czechoslovakia, Soviet Union',
#  'North Korea, Japan',
#  'USA, Japan, France',
#  'USA, Netherlands, Italy',
#  'France, Portugal, West Germany, Switzerland',
#  'Sweden, UK, Cuba',
#  'Argentina, France',
#  'Colombia, Cuba',
#  'Italy, Spain, Turkey',
#  'Cuba, Spain, West Germany',
#  'Philippines, Italy',
#  'Austria, West Germany, Switzerland',
#  'UK, Netherlands',
#  'Tunisia, France, Italy',
#  'France, Denmark',
#  'Portugal, Spain',
#  'Italy, Netherlands Antilles',
#  'Turkey, France',
#  'UK, Ireland',
#  'USA, Austria',
#  'UK, West Germany, France',
#  'Netherlands, South Korea',
#  'Canada, Hong Kong',
#  'India, Switzerland, Belgium, France',
#  'UK, Italy, Sweden',
#  'USA, China',
#  'UK, Kenya',
#  'USA, Israel, Canada',
#  'USA, Finland',
#  'France, Argentina',
#  'Hong Kong, Yugoslavia',
#  'Tunisia',
#  'Switzerland, Italy, France',
#  'Greece, France, Italy',
#  'Australia, New Zealand, UK',
#  'USA, Italy, South Korea',
#  'UK, USA, France',
#  'Sweden, France, UK',
#  'Brazil, France',
#  'Netherlands, Italy, USA',
#  'Denmark, France',
#  'West Germany, Czechoslovakia',
#  'West Germany, Portugal, France, Netherlands',
#  'Burkina Faso, Mauritania, France',
#  'Canada, USA, Mexico',
#  'Hong Kong, New Zealand',
#  'Argentina, Netherlands',
#  'USA, Canada, UK',
#  'Switzerland, France, Luxembourg',
#  'Soviet Union, Poland, Czechoslovakia, West Germany',
#  'USA, Taiwan, Japan, China, Canada',
#  'Poland, Hungary',
#  'Senegal, Algeria, Tunisia',
#  'Switzerland, Canada, France',
#  'Soviet Union, West Germany',
#  'Italy, France, Canada, USA',
#  'USA, Mexico, Spain',
#  'Italy, France, Colombia',
#  'Poland, Canada',
#  'UK, Argentina',
#  'Italy, Philippines, India',
#  'West Germany, Israel',
#  'Finland, Switzerland, West Germany',
#  'Sweden, Denmark, Norway',
#  'Mexico, Italy, USA',
#  'West Germany, USA, UK',
#  'Italy, Spain, Tunisia',
#  'Gibraltar',
#  'Japan, USA, Canada',
#  'USA, Bahamas, France, Switzerland',
#  'UK, Italy, France',
#  'Belgium, Netherlands, France',
#  'Sweden, Soviet Union, Norway',
#  'UK, Denmark, Yugoslavia, USA',
#  'Czechoslovakia, West Germany, Austria, France, Spain, Italy',
#  'Albania',
#  'France, Greece',
#  'Yugoslavia, France, USA',
#  'USA, Taiwan',
#  'West Germany, Turkey',
#  'France, Belgium, Palestine',
#  'Belgium, France, Zaire',
#  'Australia, Belgium',
#  'South Africa, USA, France',
#  'Argentina, West Germany',
#  'Canada, USA, Norway',
#  'Turkey, USA',
#  'Peru, Spain',
#  'Argentina, Canada, Netherlands',
#  'Italy, Austria, West Germany, Canada',
#  'Portugal, France, West Germany, Italy, Switzerland',
#  'France, West Germany, Cameroon',
#  'West Germany, Ghana',
#  'USA, Peru',
#  'Spain, UK, USA',
#  'Sri Lanka, USA',
#  'USA, Israel, Austria, Spain',
#  'Hungary, West Germany, Austria',
#  'Ireland, UK, USA',
#  'USA, Canada, UK, South Africa',
#  'Sweden, Iceland, Norway',
#  'Canada, Israel',
#  'South Africa, UK',
#  'Czechoslovakia, Switzerland, UK, West Germany',
#  'Japan, Switzerland',
#  'UK, India, France',
#  'Poland, Russia, USA',
#  'Cuba, Italy, Spain',
#  'Netherlands, France, West Germany',
#  'UK, Ireland, USA',
#  'Argentina, Puerto Rico',
#  'Netherlands, UK, Denmark, West Germany, Sweden',
#  'USA, Yugoslavia',
#  'Italy, Colombia',
#  'West Germany, Soviet Union',
#  'USA, UK, West Germany',
#  'UK, Zimbabwe',
#  'Canada, Switzerland',
#  'Denmark, France, Poland',
#  'USA, Canada, South Africa',
#  'France, Switzerland, Belgium',
#  'Hungary, West Germany, Cuba',
#  'France, Spain, Yugoslavia',
#  'South Africa, USA, Zaire',
#  'Canada, Hungary',
#  'Netherlands, UK, France',
#  'Australia, Canada, USA',
#  'Philippines, USA, Australia',
#  'UK, Italy, Yugoslavia',
#  'UK, Hungary',
#  'West Germany, France, Soviet Union, Switzerland',
#  'Argentina, UK',
#  'USA, Switzerland',
#  'USA, UK, France',
#  'Philippines, France',
#  'Soviet Union, Sweden',
#  'Canada, Japan',
#  'West Germany, Hungary',
#  'Puerto Rico',
#  'Netherlands, Hungary',
#  'Indonesia, Australia',
#  'USA, UK, Hungary',
#  'Belgium, France, Netherlands',
#  'USA, South Africa, Namibia',
#  'UK, France, Spain',
#  'France, West Germany, UK',
#  'USA, UK, South Africa, Israel',
#  'USA, West Germany, Austria',
#  'France, Italy, West Germany, Canada, UK',
#  'UK, Egypt',
#  'Australia, USA, Philippines',
#  'Canada, UK, Italy',
#  'Hong Kong, Australia',
#  'Yugoslavia, Canada',
#  'Colombia, USA',
#  'Argentina, Canada',
#  'Belgium, France, Italy, USA',
#  'USA, New Zealand',
#  'Burkina Faso, Switzerland, France, West Germany',
#  'New Zealand, Australia, UK, USA',
#  'Italy, Germany',
#  'Soviet Union, Italy, Switzerland',
#  'Canada, China, France',
#  'Spain, Belgium, Bulgaria',
#  'Germany, Canada, Portugal',
#  'Chile, Spain',
#  'Canada, Romania',
#  'USA, China, Hong Kong',
#  'USA, Italy, UK',
#  'Italy, France, Switzerland',
#  'USA, Bulgaria',
#  'Germany, Italy, France',
#  'USA, Australia, Yugoslavia, UK',
#  'Hong Kong, USA, China',
#  'Peru, USA',
#  'UK, Germany, Japan',
#  'Sweden, Hungary',
#  'France, Australia, USA',
#  'USA, Germany',
#  'Germany, France, Poland',
#  'Norway, Sweden, USA',
#  'Finland, Sweden, Germany, France, UK',
#  'Portugal, Germany',
#  'France, Egypt',
#  'USA, Taiwan, Philippines, China',
#  'Poland, Denmark',
#  'Poland, Germany, UK',
#  'Soviet Union, Sweden, Canada',
#  'Spain, UK',
#  'UK, Japan, USA',
#  'France, Canada, Italy, Netherlands',
#  'Czechoslovakia, Canada',
#  'Switzerland, Argentina, Japan, USA',
#  'Iran, Turkey',
#  'Portugal, Spain, France',
#  'Soviet Union, France, Austria',
#  'Czechoslovakia, France, UK',
#  'UK, France, Italy, Austria',
#  'Switzerland, Turkey, UK, France',
#  'USA, Japan, UK',
#  'India, France, UK',
#  'Russia, Soviet Union',
#  'Australia, Poland',
#  'Soviet Union, France',
#  'Switzerland, UK, France, Burkina Faso, Germany',
#  'France, Netherlands, UK, Germany, Italy, USA',
#  'Canada, USA, UK',
#  'Hong Kong, UK',
#  'Soviet Union, Uzbekistan',
#  'India, France',
#  'India, Soviet Union',
#  'France, UK, Vietnam',
#  'Germany, UK, France',
#  'Spain, Netherlands, UK',
#  'China, Germany, UK',
#  'Germany, France, Australia',
#  'Canada, Australia, USA',
#  'Iceland, Norway, Germany',
#  'Mexico, Spain, USA, UK',
#  'UK, France, Germany, USA',
#  'Italy, Portugal',
#  'Sweden, Finland, Germany',
#  'Colombia, Cuba, Spain',
#  'China, Hong Kong, Taiwan',
#  'Spain, Bulgaria',
#  'USA, Russia',
#  'Portugal, France, Switzerland',
#  'Italy, France, Belgium',
#  'France, Poland, Norway',
#  'Denmark, Sweden, Norway, Finland',
#  'Netherlands, Belgium, France',
#  'France, Israel, Canada',
#  'Denmark, Sweden, France, Germany, Switzerland, Poland',
#  'UK, France, Argentina',
#  'Switzerland, Spain, France',
#  'France, Germany, Greece, UK',
#  'France, Belgium, Italy',
#  'Norway, Denmark, Sweden, Iceland',
#  'UK, Japan, USA, Canada',
#  'India, Kenya',
#  'Norway, Sweden, Germany, France',
#  'UK, Japan, USA, Hungary',
#  'Italy, Hungary',
#  'UK, USA, South Africa',
#  'Canada, UK, Japan',
#  'France, Italy, Switzerland',
#  'France, UK, Germany, USA, Japan',
#  'Belgium, France, Switzerland',
#  'Sweden, Norway, Denmark',
#  'UK, Netherlands, France, Italy, Japan',
#  'Canada, Germany, UK, USA',
#  'Canada, Japan, USA',
#  'Germany, France, Canada, Italy, Argentina, UK, South Africa',
#  'Belgium, France, Germany',
#  'Soviet Union, Lithuania',
#  'Soviet Union, UK',
#  'Soviet Union, Switzerland, Italy',
#  'UK, France, Germany, Spain',
#  'Poland, Germany',
#  'USA, Finland, Brazil, France, Canada, Germany, UK',
#  'Ukraine',
#  'Armenia, Germany',
#  'USA, UK, Canada, Taiwan',
#  'Spain, Portugal, France',
#  'Austria, Switzerland',
#  'France, Tunisia, Germany',
#  'Germany, Switzerland',
#  'Italy, Soviet Union, USA',
#  'UK, France, Italy, Japan, USA',
#  'UK, USA, Spain',
#  'Ukraine, France',
#  'Latvia',
#  'Federal Republic of Yugoslavia, Yugoslavia',
#  ...]

# %%
df_mov_nam.metascore.max()
# Out:
# 100.0

# %%
df_mov_nam.reviews_from_users.max()
# Out:
# 10472.0

# %%
df_mov_nam.reviews_from_users.min()
# Out:
# 1.0

# %%
df_mov_nam.reviews_from_critics.max()
# Out:
# 999.0

# %%
print(df_mov_nam["title"].reviews_from_users.max())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-84d7af32a13d> in <module>
# ----> 1 print(df_mov_nam["title"].reviews_from_users.max())
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'reviews_from_users'
